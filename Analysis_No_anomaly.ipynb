# %%
import boto3
import botocore
import sagemaker
import sys


bucket = 'sciforma-performance-data'   # <--- specify a bucket you have access to
prefix = 'sagemaker/rcf-benchmarks'
execution_role = sagemaker.get_execution_role()


# check if the bucket exists
try:
    boto3.Session().client('s3').head_bucket(Bucket=bucket)
except botocore.exceptions.ParamValidationError as e:
    print('Hey! You either forgot to specify your S3 bucket'
          ' or you gave your bucket an invalid name!')
except botocore.exceptions.ClientError as e:
    if e.response['Error']['Code'] == '403':
        print("Hey! You don't have permission to access the bucket, {}.".format(bucket))
    elif e.response['Error']['Code'] == '404':
        print("Hey! Your bucket, {}, doesn't exist!".format(bucket))
    else:
        raise
else:
    print('Training input/output will be stored in: s3://{}/{}'.format(bucket, prefix))


import pandas as pd
from sagemaker import get_execution_role

role = get_execution_role()
data_key = 'performanceDataWithRole_Loc_mag_project_resource.csv'
data_location = 's3://{}/{}'.format(bucket, data_key)

performanceData = pd.read_csv(data_location)
performanceData.drop(columns='Unnamed: 0', inplace=True)
performanceData['ELAPSED'] = performanceData['ELAPSED'].div(1000) 
performanceData.drop(performanceData[performanceData['ELAPSED']>1500].index, inplace=True)
performanceData.head()
# Out:
# Training input/output will be stored in: s3://sciforma-performance-data/sagemaker/rcf-benchmarks
#              STARTDATE  ELAPSED   USERID     EVENTID         EVENT_DESC  \
# 0  2019-04-06 16:22:34    2.324  2493686  BkTdYe4nUz  Project Resources
# 1  2019-04-06 17:45:20    7.978  8929278  BkTdYe4nUz  Project Resources
# 2  2019-04-06 17:49:06    3.960  8929278  BkTdYe4nUz  Project Resources
# 3  2019-04-06 17:50:49    4.537  8929278  BkTdYe4nUz  Project Resources
# 4  2019-04-06 17:54:16    4.846  8929278  BkTdYe4nUz  Project Resources
#
#   WORKSPACEID    WS_DESC  TRANSACTIONTYPE   CORE_ID           HR_ORGANIZATION  \
# 0              Exception                1     wpmsp  The Demo Org.SP Demo Org
# 1              Exception                1  NXA24209                  HPMS.STI
# 2              Exception                1  NXA24209                  HPMS.STI
# 3              Exception                1  NXA24209                  HPMS.STI
# 4              Exception                1  NXA24209                  HPMS.STI
#
#       LOCATION         USER_ROLE MAG_CODE
# 0         TX30  _Program Manager      RB4
# 1  IN-BLR01-s1  _Program Manager      RC9
# 2  IN-BLR01-s1  _Program Manager      RC9
# 3  IN-BLR01-s1  _Program Manager      RC9
# 4  IN-BLR01-s1  _Program Manager      RC9

# %%
# !pip install git
# Out:
# Collecting git
#   Could not find a version that satisfies the requirement git (from versions: )
# No matching distribution found for git
# You are using pip version 10.0.1, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
performanceData.median()
# Out:
# ELAPSED            4.477500e+00
# USERID             8.697462e+06
# TRANSACTIONTYPE    1.000000e+00
# dtype: float64

# %%
performanceData.ELAPSED.median()

performanceData.ELAPSED.describe()
#performanceData["time_bin"]= ['0_to_1' if ((x <= 1) and (x >0)) else '2_to_more' for x in performanceData['ELAPSED']]  
    
def time_bin_method(df):
    if (0 < df['ELAPSED'] <= 2):
        return '0_to_2'
    elif (2 < df['ELAPSED'] <= 4):
        return '2_to_4'
    elif (4 < df['ELAPSED'] <= 6):
        return '4_to_6'
    elif (df['ELAPSED'] > 6):
        return '6_or_more'

def time_bin_method_pr(df):
    if (0 < df['ELAPSED'] <= 4.4):
        return '0_to_4.4'
    else :
        return '4.4_or_more'    
performanceData['time_bin'] = performanceData.apply(time_bin_method_pr, axis = 1)
#performanceData.loc[(performanceData.ELAPSED >= 0) and (performanceData.ELAPSED < 1), 'time_bin'] = '0_to_1'  
performanceData.head()
# Out:
#              STARTDATE  ELAPSED   USERID     EVENTID         EVENT_DESC  \
# 0  2019-04-06 16:22:34    2.324  2493686  BkTdYe4nUz  Project Resources
# 1  2019-04-06 17:45:20    7.978  8929278  BkTdYe4nUz  Project Resources
# 2  2019-04-06 17:49:06    3.960  8929278  BkTdYe4nUz  Project Resources
# 3  2019-04-06 17:50:49    4.537  8929278  BkTdYe4nUz  Project Resources
# 4  2019-04-06 17:54:16    4.846  8929278  BkTdYe4nUz  Project Resources
#
#   WORKSPACEID    WS_DESC  TRANSACTIONTYPE   CORE_ID           HR_ORGANIZATION  \
# 0              Exception                1     wpmsp  The Demo Org.SP Demo Org
# 1              Exception                1  NXA24209                  HPMS.STI
# 2              Exception                1  NXA24209                  HPMS.STI
# 3              Exception                1  NXA24209                  HPMS.STI
# 4              Exception                1  NXA24209                  HPMS.STI
#
#       LOCATION         USER_ROLE MAG_CODE     time_bin
# 0         TX30  _Program Manager      RB4     0_to_4.4
# 1  IN-BLR01-s1  _Program Manager      RC9  4.4_or_more
# 2  IN-BLR01-s1  _Program Manager      RC9     0_to_4.4
# 3  IN-BLR01-s1  _Program Manager      RC9  4.4_or_more
# 4  IN-BLR01-s1  _Program Manager      RC9  4.4_or_more

# %%
filters = ['4.4_or_more']
performance_subset = performanceData[performanceData.time_bin.isin(filters)]
#performance_subset = performanceData
#datasetApriori = performance_subset.drop(performance_subset.columns.difference(['HR_ORGANIZATION','LOCATION','USER_ROLE','time_bin']), 1)
datasetApriori = performance_subset.drop(performance_subset.columns.difference(['HR_ORGANIZATION','LOCATION','USER_ROLE']), 1)
datasetApriori.dropna(inplace = True)
datasetApriori = datasetApriori.values.tolist()
#print(datasetApriori)

# %%
# Apriori analysis
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

te = TransactionEncoder()
te_ary = te.fit(datasetApriori).transform(datasetApriori)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#        <No Rights>  AT-GRK01-s1  BE-LEU01-s1  BR-CPQ01  CA-KAN01  CN-BJS01  \
# 0            False        False        False     False     False     False
# 1            False        False        False     False     False     False
# 2            False        False        False     False     False     False
# 3            False        False        False     False     False     False
# 4            False        False        False     False     False     False
# 5            False        False        False     False     False     False
# 6            False         True        False     False     False     False
# 7            False        False        False     False     False     False
# 8            False        False        False     False     False     False
# 9            False        False        False     False     False     False
# 10           False        False        False     False     False     False
# 11           False        False        False     False     False     False
# 12           False        False        False     False     False     False
# 13           False        False        False     False     False     False
# 14           False        False        False     False     False     False
# 15           False        False        False     False     False     False
# 16           False        False        False     False     False     False
# 17           False        False        False     False     False     False
# 18           False        False        False     False     False     False
# 19           False        False        False     False     False     False
# 20           False        False        False     False     False     False
# 21           False        False        False     False     False     False
# 22           False        False        False     False     False     False
# 23           False        False        False     False     False     False
# 24           False        False        False     False     False     False
# 25           False        False        False     False     False     False
# 26           False        False        False     False     False     False
# 27           False        False        False     False     False     False
# 28           False        False        False     False     False     False
# 29           False        False        False     False     False     False
# ...            ...          ...          ...       ...       ...       ...
# 10951        False        False        False     False     False     False
# 10952        False        False        False     False     False     False
# 10953        False        False        False     False     False     False
# 10954        False        False        False     False     False     False
# 10955        False        False        False     False     False     False
# 10956        False        False        False     False     False     False
# 10957        False        False        False     False     False     False
# 10958        False        False        False     False     False     False
# 10959        False        False        False     False     False     False
# 10960        False        False        False     False     False     False
# 10961        False        False        False     False     False     False
# 10962        False        False        False     False     False     False
# 10963        False        False        False     False     False     False
# 10964        False        False        False     False     False     False
# 10965        False        False        False     False     False     False
# 10966        False         True        False     False     False     False
# 10967        False        False        False     False     False     False
# 10968        False         True        False     False     False     False
# 10969        False        False        False     False     False     False
# 10970        False        False        False     False     False     False
# 10971        False         True        False     False     False     False
# 10972        False        False        False     False     False     False
# 10973        False         True        False     False     False     False
# 10974        False        False        False     False     False     False
# 10975        False        False        False     False     False     False
# 10976        False        False        False     False     False     False
# 10977        False        False        False     False     False     False
# 10978        False        False        False     False     False     False
# 10979        False        False        False     False     False     False
# 10980        False        False        False     False     False     False
#
#        CN-CDU01  CN-CQI02  CN-SHA01-s1  CN-SHA02  ...  _PLM+RM  _PM+RM  \
# 0         False     False        False     False  ...    False   False
# 1         False     False        False     False  ...    False   False
# 2         False     False        False     False  ...    False   False
# 3         False     False        False     False  ...    False   False
# 4         False     False        False     False  ...    False    True
# 5         False     False        False     False  ...    False    True
# 6         False     False        False     False  ...    False    True
# 7         False     False         True     False  ...    False   False
# 8         False     False        False     False  ...    False   False
# 9         False     False        False     False  ...    False   False
# 10        False     False        False     False  ...    False    True
# 11        False     False        False     False  ...    False   False
# 12        False     False        False     False  ...    False    True
# 13        False     False        False     False  ...    False    True
# 14        False     False        False     False  ...    False    True
# 15        False     False        False      True  ...    False   False
# 16        False     False        False     False  ...    False    True
# 17        False     False        False     False  ...    False    True
# 18        False     False        False     False  ...    False   False
# 19        False     False        False     False  ...    False   False
# 20        False     False        False     False  ...    False    True
# 21        False     False        False     False  ...    False   False
# 22        False     False        False     False  ...    False    True
# 23        False     False        False     False  ...    False    True
# 24        False     False        False     False  ...    False   False
# 25        False     False        False     False  ...    False   False
# 26        False     False        False     False  ...    False    True
# 27        False     False        False     False  ...    False   False
# 28        False     False        False     False  ...    False    True
# 29        False     False        False     False  ...    False    True
# ...         ...       ...          ...       ...  ...      ...     ...
# 10951     False     False        False     False  ...    False   False
# 10952     False     False        False     False  ...    False   False
# 10953     False     False        False     False  ...    False   False
# 10954     False     False        False     False  ...    False   False
# 10955     False     False        False     False  ...    False   False
# 10956     False     False        False     False  ...    False   False
# 10957     False     False        False     False  ...    False   False
# 10958     False     False        False     False  ...    False   False
# 10959     False     False        False     False  ...    False    True
# 10960     False     False        False     False  ...    False   False
# 10961     False     False        False     False  ...    False    True
# 10962     False     False        False     False  ...    False   False
# 10963     False     False         True     False  ...    False    True
# 10964     False     False         True     False  ...    False   False
# 10965     False     False        False     False  ...    False    True
# 10966     False     False        False     False  ...    False   False
# 10967     False     False        False     False  ...    False   False
# 10968     False     False        False     False  ...    False    True
# 10969     False     False        False     False  ...    False   False
# 10970     False     False        False     False  ...    False   False
# 10971     False     False        False     False  ...    False    True
# 10972     False     False        False     False  ...    False    True
# 10973     False     False        False     False  ...    False   False
# 10974     False     False        False     False  ...    False    True
# 10975     False     False        False     False  ...    False    True
# 10976     False     False        False     False  ...    False   False
# 10977     False     False        False     False  ...    False   False
# 10978     False     False        False     False  ...    False    True
# 10979     False     False        False     False  ...    False    True
# 10980     False     False        False     False  ...    False    True
#
#        _PM+RM+Portfolio  _PMO+RM  _PMO+RM View Only  \
# 0                 False    False              False
# 1                 False    False              False
# 2                 False    False              False
# 3                 False    False              False
# 4                 False    False              False
# 5                 False    False              False
# 6                 False    False              False
# 7                 False    False              False
# 8                 False    False              False
# 9                 False    False              False
# 10                False    False              False
# 11                False    False              False
# 12                False    False              False
# 13                False    False              False
# 14                False    False              False
# 15                False    False              False
# 16                False    False              False
# 17                False    False              False
# 18                False    False              False
# 19                False     True              False
# 20                False    False              False
# 21                False     True              False
# 22                False    False              False
# 23                False    False              False
# 24                False     True              False
# 25                False     True              False
# 26                False    False              False
# 27                False    False              False
# 28                False    False              False
# 29                False    False              False
# ...                 ...      ...                ...
# 10951             False     True              False
# 10952             False     True              False
# 10953             False    False              False
# 10954             False     True              False
# 10955             False     True              False
# 10956             False     True              False
# 10957             False    False              False
# 10958             False    False              False
# 10959             False    False              False
# 10960             False    False              False
# 10961             False    False              False
# 10962             False     True              False
# 10963             False    False              False
# 10964             False    False              False
# 10965             False    False              False
# 10966             False    False              False
# 10967             False     True              False
# 10968             False    False              False
# 10969             False    False              False
# 10970             False     True              False
# 10971             False    False              False
# 10972             False    False              False
# 10973             False     True              False
# 10974             False    False              False
# 10975             False    False              False
# 10976             False    False              False
# 10977             False    False              False
# 10978             False    False              False
# 10979             False    False              False
# 10980             False    False              False
#
#        _Product Engineering Manager  _Product Line Marketer  _Program Manager  \
# 0                             False                   False              True
# 1                             False                   False              True
# 2                             False                   False              True
# 3                             False                   False              True
# 4                             False                   False             False
# 5                             False                   False             False
# 6                             False                   False             False
# 7                             False                   False              True
# 8                             False                   False              True
# 9                             False                   False              True
# 10                            False                   False             False
# 11                            False                   False              True
# 12                            False                   False             False
# 13                            False                   False             False
# 14                            False                   False             False
# 15                            False                   False              True
# 16                            False                   False             False
# 17                            False                   False             False
# 18                            False                   False              True
# 19                            False                   False             False
# 20                            False                   False             False
# 21                            False                   False             False
# 22                            False                   False             False
# 23                            False                   False             False
# 24                            False                   False             False
# 25                            False                   False             False
# 26                            False                   False             False
# 27                            False                   False              True
# 28                            False                   False             False
# 29                            False                   False             False
# ...                             ...                     ...               ...
# 10951                         False                   False             False
# 10952                         False                   False             False
# 10953                         False                   False             False
# 10954                         False                   False             False
# 10955                         False                   False             False
# 10956                         False                   False             False
# 10957                         False                   False              True
# 10958                         False                   False             False
# 10959                         False                   False             False
# 10960                         False                   False              True
# 10961                         False                   False             False
# 10962                         False                   False             False
# 10963                         False                   False             False
# 10964                         False                   False              True
# 10965                         False                   False             False
# 10966                         False                   False              True
# 10967                         False                   False             False
# 10968                         False                   False             False
# 10969                         False                   False              True
# 10970                         False                   False             False
# 10971                         False                   False             False
# 10972                         False                   False             False
# 10973                         False                   False             False
# 10974                         False                   False             False
# 10975                         False                   False             False
# 10976                         False                   False              True
# 10977                         False                   False              True
# 10978                         False                   False             False
# 10979                         False                   False             False
# 10980                         False                   False             False
#
#        _Resource Controller  _Resource Manager
# 0                     False              False
# 1                     False              False
# 2                     False              False
# 3                     False              False
# 4                     False              False
# 5                     False              False
# 6                     False              False
# 7                     False              False
# 8                     False              False
# 9                     False              False
# 10                    False              False
# 11                    False              False
# 12                    False              False
# 13                    False              False
# 14                    False              False
# 15                    False              False
# 16                    False              False
# 17                    False              False
# 18                    False              False
# 19                    False              False
# 20                    False              False
# 21                    False              False
# 22                    False              False
# 23                    False              False
# 24                    False              False
# 25                    False              False
# 26                    False              False
# 27                    False              False
# 28                    False              False
# 29                    False              False
# ...                     ...                ...
# 10951                 False              False
# 10952                 False              False
# 10953                 False              False
# 10954                 False              False
# 10955                 False              False
# 10956                 False              False
# 10957                 False              False
# 10958                 False              False
# 10959                 False              False
# 10960                 False              False
# 10961                 False              False
# 10962                 False              False
# 10963                 False              False
# 10964                 False              False
# 10965                 False              False
# 10966                 False              False
# 10967                 False              False
# 10968                 False              False
# 10969                 False              False
# 10970                 False              False
# 10971                 False              False
# 10972                 False              False
# 10973                 False              False
# 10974                 False              False
# 10975                 False              False
# 10976                 False              False
# 10977                 False              False
# 10978                 False              False
# 10979                 False              False
# 10980                 False              False
#
# [10981 rows x 81 columns]

# %%
performanceData['time_bin'].describe()

#apriori(df, min_support=0.05)
# Out:
# count           21858
# unique              2
# top       4.4_or_more
# freq            11084
# Name: time_bin, dtype: object

# %%
frequent_itemsets= apriori(df, min_support=0.001, use_colnames=True)
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
frequent_itemsets.tail(10)
# Out:
#       support                                           itemsets  length
# 385  0.001002  (The Support IT.A Support PMO, _Core Team User...       3
# 386  0.005737            (_Program Manager, RU-MOW02, T&O.TO-PT)       3
# 387  0.003187       (SG-SGP01-s4, _Program Manager, T&O.SSC-GTI)       3
# 388  0.009471                   (_PMO+RM, US-AUS01, T&O.SSC-GTI)       3
# 389  0.001548          (US-AUS01, _Program Manager, T&O.SSC-GTI)       3
# 390  0.001730                   (_PMO+RM, US-CHD01, T&O.SSC-QAL)       3
# 391  0.002277                     (_PMO+RM, US-AUS01, T&O.TO-FO)       3
# 392  0.007012                     (_PMO+RM, US-AUS02, T&O.TO-FO)       3
# 393  0.001366                     (_PMO+RM, T&O.TO-FO, US-CHD01)       3
# 394  0.001821                      (T&O.TO-PT, _PM+RM, US-CHD01)       3

# %%
from mlxtend.frequent_patterns import association_rules
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=2)
#rules.to_csv("project_scheduler_rules_mlxtend.csv")

# %%
confidence = rules['confidence'] > 0.8
lift = rules['lift'] > 20
#elderly = df['age'] > 50

rules= rules.sort_values(by=['confidence','lift'], ascending=False)
rules[confidence]
# Out:
#                                            antecedents  \
# 176          (The Support IT.A Support PMO, 6_or_more)
# 293              (_Core Team Support User, NXP-REMOTE)
# 394  (4_to_6, _Core Team Support User, The Support ...
# 461               (_Core Team Support User, 6_or_more)
# 459   (_Core Team Support User, 6_or_more, NXP-REMOTE)
# 458  (_Core Team Support User, 6_or_more, The Suppo...
# 395      (4_to_6, _Core Team Support User, NXP-REMOTE)
# 120             (4_to_6, The Support IT.A Support PMO)
# 48                           (_Core Team Support User)
# 54                           (_Core Team Support User)
# 186               (_Core Team Support User, 6_or_more)
# 177                            (6_or_more, NXP-REMOTE)
# 124                  (4_to_6, _Core Team Support User)
# 121                               (4_to_6, NXP-REMOTE)
# 295                          (_Core Team Support User)
# 180               (_Core Team Support User, 6_or_more)
# 132                  (4_to_6, _Core Team Support User)
# 46                      (The Support IT.A Support PMO)
# 47                                        (NXP-REMOTE)
# 397                  (4_to_6, _Core Team Support User)
# 292  (_Core Team Support User, The Support IT.A Sup...
# 51                                          (US-AUS02)
# 69                                  (4_to_6, CN-SZH02)
# 324  (4_to_6, HPMS.Kechichian, Kevork - NXF53803, C...
# 9                                           (CN-SZH02)
# 208     (HPMS.Kechichian, Kevork - NXF53803, CN-SZH02)
# 248                            (HPMS.CBS, NL-NYM01-s1)
# 419                    (DE-HBG02, 6_or_more, HPMS.IDA)
# 5                                           (CN-SHA02)
# 465                            (6_or_more, NXP-REMOTE)
# ..                                                 ...
# 297                                       (NXP-REMOTE)
# 296                     (The Support IT.A Support PMO)
# 49                                        (NXP-REMOTE)
# 55                      (The Support IT.A Support PMO)
# 431           (_Resource Manager, 6_or_more, IN-NDA02)
# 406                   (AT-GRK01-s1, 6_or_more, _PM+RM)
# 243                               (HPMS.AMP, IN-NDA02)
# 153                              (6_or_more, HPMS.IDA)
# 364                      (4_to_6, _PM+RM, IN-BLR01-s1)
# 267                              (HPMS.MICR, US-AUS01)
# 125                               (4_to_6, NXP-REMOTE)
# 399                               (4_to_6, NXP-REMOTE)
# 398             (4_to_6, The Support IT.A Support PMO)
# 396  (4_to_6, The Support IT.A Support PMO, NXP-REM...
# 133             (4_to_6, The Support IT.A Support PMO)
# 27                                          (HPMS.IDA)
# 7                                           (CN-SZH02)
# 207                      (_Resource Manager, CN-SZH02)
# 211                                         (CN-SZH02)
# 447                 (HPMS.STI, 6_or_more, IN-BLR01-s1)
# 274                              (_PM+RM, IN-BLR01-s1)
# 36                                            (_PE+RM)
# 191                            (HPMS.AAA, AT-GRK01-s1)
# 196                              (AT-GRK01-s1, _PM+RM)
# 418           (DE-HBG02, _Resource Manager, 6_or_more)
# 411                     (_PMO+RM, 6_or_more, HPMS.STI)
# 327                                 (4_to_6, CN-SZH02)
# 65                                  (4_to_6, CN-SZH02)
# 323              (4_to_6, _Resource Manager, CN-SZH02)
# 212                               (DE-HBG02, HPMS.CBS)
#
#                                            consequents  antecedent support  \
# 176                                       (NXP-REMOTE)            0.020883
# 293                     (The Support IT.A Support PMO)            0.030725
# 394                                       (NXP-REMOTE)            0.010802
# 461         (The Support IT.A Support PMO, NXP-REMOTE)            0.019923
# 459                     (The Support IT.A Support PMO)            0.019923
# 458                                       (NXP-REMOTE)            0.019923
# 395                     (The Support IT.A Support PMO)            0.010802
# 120                                       (NXP-REMOTE)            0.012482
# 48                                        (NXP-REMOTE)            0.030725
# 54                      (The Support IT.A Support PMO)            0.030725
# 186                     (The Support IT.A Support PMO)            0.019923
# 177                     (The Support IT.A Support PMO)            0.020883
# 124                                       (NXP-REMOTE)            0.010802
# 121                     (The Support IT.A Support PMO)            0.012482
# 295         (The Support IT.A Support PMO, NXP-REMOTE)            0.030725
# 180                                       (NXP-REMOTE)            0.019923
# 132                     (The Support IT.A Support PMO)            0.010802
# 46                                        (NXP-REMOTE)            0.033365
# 47                      (The Support IT.A Support PMO)            0.033365
# 397         (The Support IT.A Support PMO, NXP-REMOTE)            0.010802
# 292                                       (NXP-REMOTE)            0.030725
# 51                                         (T&O.TO-FO)            0.015362
# 69                                 (_Resource Manager)            0.012482
# 324                                (_Resource Manager)            0.010082
# 9                                  (_Resource Manager)            0.021843
# 208                                (_Resource Manager)            0.018483
# 248                                           (_PM+RM)            0.013202
# 419                                (_Resource Manager)            0.016323
# 5                                  (_Resource Manager)            0.014882
# 465  (_Core Team Support User, The Support IT.A Sup...            0.020883
# ..                                                 ...                 ...
# 297  (_Core Team Support User, The Support IT.A Sup...            0.033365
# 296              (_Core Team Support User, NXP-REMOTE)            0.033365
# 49                           (_Core Team Support User)            0.033365
# 55                           (_Core Team Support User)            0.033365
# 431               (HPMS.Kechichian, Kevork - NXF53803)            0.013682
# 406                                         (HPMS.STI)            0.016083
# 243                                           (_PM+RM)            0.018243
# 153                                (_Resource Manager)            0.037926
# 364                                         (HPMS.STI)            0.048248
# 267                                          (_PMO+RM)            0.014882
# 125                          (_Core Team Support User)            0.012482
# 399  (_Core Team Support User, The Support IT.A Sup...            0.012482
# 398              (_Core Team Support User, NXP-REMOTE)            0.012482
# 396                          (_Core Team Support User)            0.012482
# 133                          (_Core Team Support User)            0.012482
# 27                                 (_Resource Manager)            0.063850
# 7                 (HPMS.Kechichian, Kevork - NXF53803)            0.021843
# 207               (HPMS.Kechichian, Kevork - NXF53803)            0.021603
# 211  (HPMS.Kechichian, Kevork - NXF53803, _Resource...            0.021843
# 447                                           (_PM+RM)            0.033365
# 274                                         (HPMS.STI)            0.085694
# 36                                          (HPMS.OPS)            0.014642
# 191                                          (_PMO+RM)            0.018483
# 196                                         (HPMS.STI)            0.044887
# 418                                         (HPMS.IDA)            0.019443
# 411                                      (AT-GRK01-s1)            0.018003
# 327  (HPMS.Kechichian, Kevork - NXF53803, _Resource...            0.012482
# 65                (HPMS.Kechichian, Kevork - NXF53803)            0.012482
# 323               (HPMS.Kechichian, Kevork - NXF53803)            0.012482
# 212                                           (_PM+RM)            0.029765
#
#      consequent support   support  confidence       lift  leverage  conviction
# 176            0.033365  0.020883    1.000000  29.971223  0.020187         inf
# 293            0.033365  0.030725    1.000000  29.971223  0.029700         inf
# 394            0.033365  0.010802    1.000000  29.971223  0.010441         inf
# 461            0.033365  0.019923    1.000000  29.971223  0.019258         inf
# 459            0.033365  0.019923    1.000000  29.971223  0.019258         inf
# 458            0.033365  0.019923    1.000000  29.971223  0.019258         inf
# 395            0.033365  0.010802    1.000000  29.971223  0.010441         inf
# 120            0.033365  0.012482    1.000000  29.971223  0.012066         inf
# 48             0.033365  0.030725    1.000000  29.971223  0.029700         inf
# 54             0.033365  0.030725    1.000000  29.971223  0.029700         inf
# 186            0.033365  0.019923    1.000000  29.971223  0.019258         inf
# 177            0.033365  0.020883    1.000000  29.971223  0.020187         inf
# 124            0.033365  0.010802    1.000000  29.971223  0.010441         inf
# 121            0.033365  0.012482    1.000000  29.971223  0.012066         inf
# 295            0.033365  0.030725    1.000000  29.971223  0.029700         inf
# 180            0.033365  0.019923    1.000000  29.971223  0.019258         inf
# 132            0.033365  0.010802    1.000000  29.971223  0.010441         inf
# 46             0.033365  0.033365    1.000000  29.971223  0.032252         inf
# 47             0.033365  0.033365    1.000000  29.971223  0.032252         inf
# 397            0.033365  0.010802    1.000000  29.971223  0.010441         inf
# 292            0.033365  0.030725    1.000000  29.971223  0.029700         inf
# 51             0.047528  0.015362    1.000000  21.040404  0.014632         inf
# 69             0.375900  0.012482    1.000000   2.660281  0.007790         inf
# 324            0.375900  0.010082    1.000000   2.660281  0.006292         inf
# 9              0.375900  0.021603    0.989011   2.631047  0.013392   56.793087
# 208            0.375900  0.018243    0.987013   2.625732  0.011295   48.055689
# 248            0.344695  0.012962    0.981818   2.848367  0.008411   36.041767
# 419            0.375900  0.015843    0.970588   2.582037  0.009707   21.219395
# 5              0.375900  0.014402    0.967742   2.574465  0.008808   19.347096
# 465            0.030725  0.019923    0.954023  31.050467  0.019282   21.081733
# ..                  ...       ...         ...        ...       ...         ...
# 297            0.030725  0.030725    0.920863  29.971223  0.029700   12.248112
# 296            0.030725  0.030725    0.920863  29.971223  0.029700   12.248112
# 49             0.030725  0.030725    0.920863  29.971223  0.029700   12.248112
# 55             0.030725  0.030725    0.920863  29.971223  0.029700   12.248112
# 431            0.155785  0.012482    0.912281   5.856027  0.010351    9.624052
# 406            0.264282  0.014402    0.895522   3.388507  0.010152    7.041870
# 243            0.344695  0.016323    0.894737   2.595734  0.010034    6.225396
# 153            0.375900  0.033845    0.892405   2.374048  0.019589    5.800457
# 364            0.264282  0.042967    0.890547   3.369682  0.030216    6.721785
# 267            0.213394  0.013202    0.887097   4.157081  0.010026    6.967080
# 125            0.030725  0.010802    0.865385  28.165565  0.010418    7.200329
# 399            0.030725  0.010802    0.865385  28.165565  0.010418    7.200329
# 398            0.030725  0.010802    0.865385  28.165565  0.010418    7.200329
# 396            0.030725  0.010802    0.865385  28.165565  0.010418    7.200329
# 133            0.030725  0.010802    0.865385  28.165565  0.010418    7.200329
# 27             0.375900  0.054489    0.853383   2.270240  0.030487    4.256681
# 7              0.155785  0.018483    0.846154   5.431551  0.015080    5.487398
# 207            0.155785  0.018243    0.844444   5.420579  0.014877    5.427097
# 211            0.107537  0.018243    0.835165   7.766287  0.015894    5.414274
# 447            0.344695  0.027604    0.827338   2.400202  0.016104    3.795307
# 274            0.264282  0.070571    0.823529   3.116098  0.047924    4.169067
# 36             0.031445  0.012002    0.819672  26.066825  0.011541    5.371078
# 191            0.213394  0.015122    0.818182   3.834134  0.011178    4.326332
# 196            0.264282  0.036726    0.818182   3.095863  0.024863    4.046447
# 418            0.063850  0.015843    0.814815  12.761348  0.014601    5.055209
# 411            0.127220  0.014642    0.813333   6.393107  0.012352    4.675605
# 327            0.107537  0.010082    0.807692   7.510817  0.008739    4.640807
# 65             0.155785  0.010082    0.807692   5.184663  0.008137    4.389918
# 323            0.155785  0.010082    0.807692   5.184663  0.008137    4.389918
# 212            0.344695  0.024004    0.806452   2.339608  0.013744    3.385742
#
# [69 rows x 9 columns]

# %%
def unionizeFrozenset(rules):
        return frozenset.union(rules['antecedents'],rules['consequents'])

performanceData['time_bin'] = performanceData.apply(time_bin_method, axis = 1)



rules['Combined_frozenset']=rules.apply(unionizeFrozenset, axis = 1)

# %%
rules.describe()
# Out:
#        antecedent support  consequent support     support  confidence  \
# count          714.000000          714.000000  714.000000  714.000000
# mean             0.076096            0.076096    0.009293    0.377477
# std              0.108714            0.108714    0.015228    0.359085
# min              0.001002            0.001002    0.001002    0.002948
# 25%              0.009858            0.009858    0.001821    0.059939
# 50%              0.027775            0.027775    0.004827    0.228155
# 75%              0.072489            0.072489    0.010291    0.678571
# max              0.392223            0.392223    0.149440    1.000000
#
#              lift    leverage  conviction
# count  714.000000  714.000000  714.000000
# mean    19.355419    0.006767         inf
# std     73.654193    0.009897         NaN
# min      2.010035    0.000531    1.001587
# 25%      2.698034    0.001398    1.047332
# 50%      4.442152    0.003100    1.236243
# 75%     12.614726    0.007690    2.612386
# max    998.272727    0.080575         inf

# %%
uninionizedRules = rules.drop(columns=['antecedents','consequents'])
uninionizedRules.describe()
# Out:
#        antecedent support  consequent support     support  confidence  \
# count          714.000000          714.000000  714.000000  714.000000
# mean             0.076096            0.076096    0.009293    0.377477
# std              0.108714            0.108714    0.015228    0.359085
# min              0.001002            0.001002    0.001002    0.002948
# 25%              0.009858            0.009858    0.001821    0.059939
# 50%              0.027775            0.027775    0.004827    0.228155
# 75%              0.072489            0.072489    0.010291    0.678571
# max              0.392223            0.392223    0.149440    1.000000
#
#              lift    leverage  conviction
# count  714.000000  714.000000  714.000000
# mean    19.355419    0.006767         inf
# std     73.654193    0.009897         NaN
# min      2.010035    0.000531    1.001587
# 25%      2.698034    0.001398    1.047332
# 50%      4.442152    0.003100    1.236243
# 75%     12.614726    0.007690    2.612386
# max    998.272727    0.080575         inf

# %%
uninionizedRules = uninionizedRules.groupby(['Combined_frozenset']).mean()

# %%
uninionizedRules.head()
# Out:
#                                         antecedent support  \
# Combined_frozenset
# (<No Rights>, GB-TON01)                           0.007877
# (HPMS.AAA, _PMO+RM, FR-TLS02)                     0.059011
# (HPMS.AAA, FR-TLS02, _Program Manager)            0.065887
# (_Program Manager, FR-TLS02, HPMS.IDA)            0.185958
# (HPMS.SEN, FR-TLS02, _Program Manager)            0.107003
#
#                                         consequent support   support  \
# Combined_frozenset
# (<No Rights>, GB-TON01)                           0.007877  0.002550
# (HPMS.AAA, _PMO+RM, FR-TLS02)                     0.059011  0.010291
# (HPMS.AAA, FR-TLS02, _Program Manager)            0.065887  0.032693
# (_Program Manager, FR-TLS02, HPMS.IDA)            0.185958  0.001275
# (HPMS.SEN, FR-TLS02, _Program Manager)            0.107003  0.001366
#
#                                         confidence       lift  leverage  \
# Combined_frozenset
# (<No Rights>, GB-TON01)                   0.596552  75.731034  0.002516
# (HPMS.AAA, _PMO+RM, FR-TLS02)             0.359286   5.834917  0.008323
# (HPMS.AAA, FR-TLS02, _Program Manager)    0.605990   9.714034  0.029100
# (_Program Manager, FR-TLS02, HPMS.IDA)    0.501720   2.698034  0.000802
# (HPMS.SEN, FR-TLS02, _Program Manager)    0.305386   3.293980  0.000937
#
#                                         conviction
# Combined_frozenset
# (<No Rights>, GB-TON01)                        inf
# (HPMS.AAA, _PMO+RM, FR-TLS02)             5.212335
# (HPMS.AAA, FR-TLS02, _Program Manager)    3.721155
# (_Program Manager, FR-TLS02, HPMS.IDA)         inf
# (HPMS.SEN, FR-TLS02, _Program Manager)         inf

# %%
uninionizedRules.to_csv("project_resource_Union_rules_mlxtend.csv")
